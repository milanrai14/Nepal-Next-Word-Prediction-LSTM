# %% [markdown]
# # This project uses an **LSTM-based Recurrent Neural Network (RNN)** to predict the next word in a sequence using a Nepal-focused text corpus. The model learns word patterns from previous context and generates the most likely next word.

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# %%
with open('../data/About Nepal.txt', 'r') as f: 
    text = f.read()

# %%
tokenzier = Tokenizer()
tokenzier.fit_on_texts([text])

# %%
tokenzier.word_index
# Out:
# {'and': 1,
#  'the': 2,
#  'of': 3,
#  'is': 4,
#  'nepal': 5,
#  'in': 6,
#  'communities': 7,
#  'a': 8,
#  'are': 9,
#  'can': 10,
#  'to': 11,
#  'important': 12,
#  'many': 13,
#  'cultural': 14,
#  'for': 15,
#  'with': 16,
#  'an': 17,
#  'people': 18,
#  'language': 19,
#  'traditional': 20,
#  'community': 21,
#  'festivals': 22,
#  'have': 23,
#  'has': 24,
#  'traditions': 25,
#  'food': 26,
#  'indigenous': 27,
#  'it': 28,
#  'as': 29,
#  'its': 30,
#  'different': 31,
#  'one': 32,
#  'region': 33,
#  'associated': 34,
#  'technology': 35,
#  'other': 36,
#  'country': 37,
#  'also': 38,
#  'be': 39,
#  'model': 40,
#  'word': 41,
#  'known': 42,
#  'from': 43,
#  'their': 44,
#  'languages': 45,
#  'music': 46,
#  'development': 47,
#  'text': 48,
#  'local': 49,
#  'mountains': 50,
#  'contains': 51,
#  'agriculture': 52,
#  'tourism': 53,
#  'areas': 54,
#  'culture': 55,
#  'natural': 56,
#  'kathmandu': 57,
#  'architecture': 58,
#  'practices': 59,
#  'knowledge': 60,
#  'diverse': 61,
#  'activities': 62,
#  'own': 63,
#  'on': 64,
#  'education': 65,
#  'data': 66,
#  'most': 67,
#  'parts': 68,
#  'rivers': 69,
#  'religious': 70,
#  'learning': 71,
#  'words': 72,
#  'dances': 73,
#  'by': 74,
#  'regions': 75,
#  'such': 76,
#  'popular': 77,
#  'clothing': 78,
#  'nepalese': 79,
#  'terai': 80,
#  'visitors': 81,
#  'systems': 82,
#  'lake': 83,
#  'identity': 84,
#  'historical': 85,
#  'heritage': 86,
#  'valley': 87,
#  'part': 88,
#  'forests': 89,
#  'mountain': 90,
#  'several': 91,
#  'help': 92,
#  'festival': 93,
#  'another': 94,
#  'well': 95,
#  'diversity': 96,
#  'nepali': 97,
#  'resources': 98,
#  'national': 99,
#  'that': 100,
#  'tamang': 101,
#  'particularly': 102,
#  'training': 103,
#  'intelligence': 104,
#  'or': 105,
#  'songs': 106,
#  'includes': 107,
#  'famous': 108,
#  'these': 109,
#  'water': 110,
#  'environment': 111,
#  'magar': 112,
#  'gurung': 113,
#  'used': 114,
#  'modern': 115,
#  'opportunities': 116,
#  'provide': 117,
#  'hills': 118,
#  'young': 119,
#  'artificial': 120,
#  'next': 121,
#  'sherpa': 122,
#  'located': 123,
#  'temples': 124,
#  'himalayan': 125,
#  'everest': 126,
#  'include': 127,
#  'trekking': 128,
#  'during': 129,
#  'ecosystems': 130,
#  'high': 131,
#  'environments': 132,
#  'across': 133,
#  'history': 134,
#  'while': 135,
#  'patterns': 136,
#  'area': 137,
#  'generation': 138,
#  'new': 139,
#  'newar': 140,
#  'beautiful': 141,
#  'economic': 142,
#  'commonly': 143,
#  'major': 144,
#  'trade': 145,
#  'villages': 146,
#  'each': 147,
#  'tharu': 148,
#  'rai': 149,
#  'society': 150,
#  'create': 151,
#  'buddhist': 152,
#  'between': 153,
#  'relationships': 154,
#  'rice': 155,
#  'transportation': 156,
#  'students': 157,
#  'machine': 158,
#  'learn': 159,
#  'sentence': 160,
#  'may': 161,
#  'stories': 162,
#  'healthcare': 163,
#  'through': 164,
#  'future': 165,
#  'life': 166,
#  'eastern': 167,
#  'mainly': 168,
#  'educational': 169,
#  'bhaktapur': 170,
#  'art': 171,
#  'hilly': 172,
#  'annapurna': 173,
#  'among': 174,
#  'experience': 175,
#  'plains': 176,
#  'river': 177,
#  'because': 178,
#  'found': 179,
#  'wildlife': 180,
#  'conservation': 181,
#  'long': 182,
#  'live': 183,
#  'limbu': 184,
#  'often': 185,
#  'family': 186,
#  'traditionally': 187,
#  'durbar': 188,
#  'square': 189,
#  "nepal's": 190,
#  'common': 191,
#  'businesses': 192,
#  'surrounding': 193,
#  'lifestyles': 194,
#  'science': 195,
#  'processing': 196,
#  'tokenization': 197,
#  'digital': 198,
#  'services': 199,
#  'lakes': 200,
#  'generations': 201,
#  'contribute': 202,
#  "country's": 203,
#  'ceremonies': 204,
#  'central': 205,
#  'world': 206,
#  'city': 207,
#  'centers': 208,
#  'geography': 209,
#  'highest': 210,
#  'landscapes': 211,
#  'cultures': 212,
#  'rich': 213,
#  'hydropower': 214,
#  'plants': 215,
#  'animals': 216,
#  'park': 217,
#  'altitude': 218,
#  'unique': 219,
#  'celebrations': 220,
#  'foods': 221,
#  'arts': 222,
#  'developed': 223,
#  'process': 224,
#  'farming': 225,
#  'agricultural': 226,
#  'crops': 227,
#  'support': 228,
#  'pokhara': 229,
#  'information': 230,
#  'increasingly': 231,
#  'tasks': 232,
#  'use': 233,
#  'predict': 234,
#  'then': 235,
#  'lstm': 236,
#  'sequence': 237,
#  'generate': 238,
#  'passed': 239,
#  'been': 240,
#  'challenges': 241,
#  'quality': 242,
#  'more': 243,
#  'temperature': 244,
#  'environmental': 245,
#  'nature': 246,
#  'sports': 247,
#  'including': 248,
#  'health': 249,
#  'social': 250,
#  'gatherings': 251,
#  'dance': 252,
#  'chepang': 253,
#  'thakali': 254,
#  'oral': 255,
#  'south': 256,
#  'north': 257,
#  'around': 258,
#  'lalitpur': 259,
#  'monuments': 260,
#  'into': 261,
#  'geographical': 262,
#  'some': 263,
#  'mount': 264,
#  'become': 265,
#  'himalayas': 266,
#  'adventure': 267,
#  'trek': 268,
#  'routes': 269,
#  'monasteries': 270,
#  'climate': 271,
#  'chitwan': 272,
#  'glaciers': 273,
#  'home': 274,
#  'term': 275,
#  'however': 276,
#  'kirat': 277,
#  'throughout': 278,
#  'dashain': 279,
#  'tihar': 280,
#  'holi': 281,
#  'chhath': 282,
#  'celebrated': 283,
#  'together': 284,
#  'sites': 285,
#  'countries': 286,
#  'visit': 287,
#  'patan': 288,
#  'temple': 289,
#  'boudhanath': 290,
#  'hill': 291,
#  'large': 292,
#  'provides': 293,
#  'buildings': 294,
#  'over': 295,
#  'smaller': 296,
#  'recognition': 297,
#  'economy': 298,
#  'vegetables': 299,
#  'depends': 300,
#  'significant': 301,
#  'sector': 302,
#  'employment': 303,
#  'phewa': 304,
#  'boating': 305,
#  'schools': 306,
#  'institutions': 307,
#  'engineering': 308,
#  'computer': 309,
#  'becoming': 310,
#  'programming': 311,
#  'mobile': 312,
#  'software': 313,
#  'human': 314,
#  'networks': 315,
#  'speech': 316,
#  'called': 317,
#  'probability': 318,
#  'prediction': 319,
#  'understand': 320,
#  'example': 321,
#  'system': 322,
#  'tokens': 323,
#  'using': 324,
#  'possible': 325,
#  'this': 326,
#  'becomes': 327,
#  'continues': 328,
#  'generated': 329,
#  'vocabulary': 330,
#  'when': 331,
#  'writing': 332,
#  'growing': 333,
#  'online': 334,
#  'made': 335,
#  'communication': 336,
#  'public': 337,
#  'research': 338,
#  'sustainable': 339,
#  'especially': 340,
#  'western': 341,
#  'cricket': 342,
#  'football': 343,
#  'play': 344,
#  'infrastructure': 345,
#  'hospitality': 346,
#  'skills': 347,
#  'how': 348,
#  'closely': 349,
#  'sunuwar': 350,
#  'hyolmo': 351,
#  'majhi': 352,
#  'bote': 353,
#  'dhimal': 354,
#  'rajbanshi': 355,
#  'strongly': 356,
#  'historically': 357,
#  'china': 358,
#  'india': 359,
#  'beauty': 360,
#  'largest': 361,
#  'highly': 362,
#  'valleys': 363,
#  'flat': 364,
#  'sagarmatha': 365,
#  'attracts': 366,
#  'researchers': 367,
#  'symbols': 368,
#  'manaslu': 369,
#  'attract': 370,
#  'who': 371,
#  'come': 372,
#  'mountaineering': 373,
#  'base': 374,
#  'camp': 375,
#  'circuit': 376,
#  'langtang': 377,
#  'trekkers': 378,
#  'southern': 379,
#  'koshi': 380,
#  'wetlands': 381,
#  'species': 382,
#  'birds': 383,
#  'protected': 384,
#  'protection': 385,
#  'ethnic': 386,
#  'groups': 387,
#  'richness': 388,
#  'year': 389,
#  'buddha': 390,
#  'families': 391,
#  'gather': 392,
#  'time': 393,
#  'participate': 394,
#  'colors': 395,
#  'sun': 396,
#  'strong': 397,
#  'lumbini': 398,
#  'pashupatinath': 399,
#  'swayambhunath': 400,
#  'hindu': 401,
#  'site': 402,
#  'stupa': 403,
#  'shops': 404,
#  'restaurants': 405,
#  'tourists': 406,
#  'courtyards': 407,
#  'attractions': 408,
#  'metalwork': 409,
#  'wood': 410,
#  'carving': 411,
#  'religion': 412,
#  'unification': 413,
#  'brought': 414,
#  'states': 415,
#  'contributed': 416,
#  'influenced': 417,
#  'politics': 418,
#  'migration': 419,
#  'service': 420,
#  'gurkha': 421,
#  'soldiers': 422,
#  'served': 423,
#  'international': 424,
#  'livestock': 425,
#  'products': 426,
#  'types': 427,
#  'rainfall': 428,
#  'relatively': 429,
#  'soil': 430,
#  'population': 431,
#  'creating': 432,
#  'potential': 433,
#  'electricity': 434,
#  'tourist': 435,
#  'views': 436,
#  'enjoy': 437,
#  'destination': 438,
#  'rural': 439,
#  'allows': 440,
#  'web': 441,
#  'cybersecurity': 442,
#  'perform': 443,
#  'understanding': 444,
#  'predictions': 445,
#  'branch': 446,
#  'computers': 447,
#  'make': 448,
#  'classification': 449,
#  'recommendation': 450,
#  'deep': 451,
#  'neural': 452,
#  'nlp': 453,
#  'translation': 454,
#  'models': 455,
#  'based': 456,
#  'appear': 457,
#  'modeling': 458,
#  'likely': 459,
#  'added': 460,
#  'network': 461,
#  'at': 462,
#  'numerical': 463,
#  'layer': 464,
#  'produces': 465,
#  'input': 466,
#  'number': 467,
#  'building': 468,
#  'forms': 469,
#  'variations': 470,
#  'units': 471,
#  'level': 472,
#  'very': 473,
#  'reduce': 474,
#  'contain': 475,
#  'books': 476,
#  'styles': 477,
#  'interested': 478,
#  'platforms': 479,
#  'change': 480,
#  'changes': 481,
#  'rara': 482,
#  'tilicho': 483,
#  'importance': 484,
#  'mountainous': 485,
#  'usually': 486,
#  'pickles': 487,
#  'momo': 488,
#  'sel': 489,
#  'roti': 490,
#  'gundruk': 491,
#  'preservation': 492,
#  'musical': 493,
#  'volleyball': 494,
#  'played': 495,
#  'flag': 496,
#  'challenging': 497,
#  'roads': 498,
#  'airports': 499,
#  'connect': 500,
#  'remote': 501,
#  'professionals': 502,
#  'innovation': 503,
#  'exist': 504,
#  'crafts': 505,
#  'continue': 506,
#  'role': 507,
#  'interesting': 508,
#  'should': 509,
#  'evaluated': 510,
#  'validation': 511,
#  'loss': 512,
#  'overfitting': 513,
#  'too': 514,
#  'but': 515,
#  'sampling': 516,
#  'instead': 517,
#  'predictable': 518,
#  'produce': 519,
#  'k': 520,
#  'develop': 521,
#  'preserving': 522,
#  'preserve': 523,
#  'possibilities': 524,
#  'about': 525,
#  'examples': 526,
#  'present': 527,
#  'peoples': 528,
#  'they': 529,
#  'greatly': 530,
#  'houses': 531,
#  'both': 532,
#  'primarily': 533,
#  'connected': 534,
#  'artwork': 535,
#  'waterways': 536,
#  'fishing': 537,
#  'elements': 538,
#  'asia': 539,
#  'landlocked': 540,
#  'surrounded': 541,
#  'east': 542,
#  'west': 543,
#  'friendly': 544,
#  'capital': 545,
#  'political': 546,
#  'divided': 547,
#  'three': 548,
#  'lies': 549,
#  'northern': 550,
#  'settlements': 551,
#  'mostly': 552,
#  'chomolungma': 553,
#  'tibetan': 554,
#  'climbers': 555,
#  'travelers': 556,
#  'adventurers': 557,
#  'ranges': 558,
#  'peaks': 559,
#  'kanchenjunga': 560,
#  'lhotse': 561,
#  'makalu': 562,
#  'cho': 563,
#  'oyu': 564,
#  'dhaulagiri': 565,
#  'thousands': 566,
#  'photography': 567,
#  'journeys': 568,
#  'originate': 569,
#  'flow': 570,
#  'toward': 571,
#  'gandaki': 572,
#  'karnali': 573,
#  'drinking': 574,
#  'irrigation': 575,
#  'wide': 576,
#  'variety': 577,
#  'grasslands': 578,
#  'mammals': 579,
#  'reptiles': 580,
#  'see': 581,
#  'greater': 582,
#  'horned': 583,
#  'rhinoceros': 584,
#  'bengal': 585,
#  'tiger': 586,
#  'wild': 587,
#  'elephant': 588,
#  'deer': 589,
#  'crocodile': 590,
#  'various': 591,
#  'adapted': 592,
#  'parks': 593,
#  'conserve': 594,
#  'biodiversity': 595,
#  'need': 596,
#  'culturally': 597,
#  'characteristics': 598,
#  'official': 599,
#  'spoken': 600,
#  'maithili': 601,
#  'bhojpuri': 602,
#  'bhasa': 603,
#  'awadhi': 604,
#  'backgrounds': 605,
#  'hinduism': 606,
#  'buddhism': 607,
#  'muslims': 608,
#  'christians': 609,
#  'contributes': 610,
#  'celebrates': 611,
#  'teej': 612,
#  'jayanti': 613,
#  'losar': 614,
#  'maghe': 615,
#  'sankranti': 616,
#  'indra': 617,
#  'jatra': 618,
#  'biggest': 619,
#  'receive': 620,
#  'tika': 621,
#  'blessings': 622,
#  'elders': 623,
#  'spend': 624,
#  'relatives': 625,
#  'lights': 626,
#  'decorate': 627,
#  'homes': 628,
#  'light': 629,
#  'lamps': 630,
#  'colorful': 631,
#  'deusi': 632,
#  'bhailo': 633,
#  'celebrate': 634,
#  'playing': 635,
#  'meeting': 636,
#  'friends': 637,
#  'enjoying': 638,
#  'worship': 639,
#  'near': 640,
#  'ponds': 641,
#  'sources': 642,
#  'significance': 643,
#  'recognized': 644,
#  'birthplace': 645,
#  'gautama': 646,
#  'purposes': 647,
#  'beside': 648,
#  'bagmati': 649,
#  'dedicated': 650,
#  'lord': 651,
#  'shiva': 652,
#  'pilgrims': 653,
#  'shrines': 654,
#  'panoramic': 655,
#  'view': 656,
#  'stupas': 657,
#  'historic': 658,
#  'newari': 659,
#  'pottery': 660,
#  'complex': 661,
#  'kingdoms': 662,
#  'became': 663,
#  'center': 664,
#  'centuries': 665,
#  'king': 666,
#  'prithvi': 667,
#  'narayan': 668,
#  'shah': 669,
#  'formation': 670,
#  'relationship': 671,
#  'neighboring': 672,
#  'location': 673,
#  'bravery': 674,
#  'military': 675,
#  'forces': 676,
#  'gained': 677,
#  'courage': 678,
#  'depend': 679,
#  'livelihoods': 680,
#  'maize': 681,
#  'wheat': 682,
#  'millet': 683,
#  'potatoes': 684,
#  'fruits': 685,
#  'cash': 686,
#  'widely': 687,
#  'cultivated': 688,
#  'suitable': 689,
#  'monsoon': 690,
#  'season': 691,
#  'heavily': 692,
#  'availability': 693,
#  'land': 694,
#  'fertile': 695,
#  'production': 696,
#  'industry': 697,
#  'farmers': 698,
#  'grow': 699,
#  'according': 700,
#  'conditions': 701,
#  'terraced': 702,
#  'differences': 703,
#  'elevation': 704,
#  'households': 705,
#  'industries': 706,
#  'scenery': 707,
#  'creates': 708,
#  'supports': 709,
#  'hotels': 710,
#  'guides': 711,
#  'destinations': 712,
#  'caves': 713,
#  'waterfalls': 714,
#  'paragliding': 715,
#  'hiking': 716,
#  'sightseeing': 717,
#  'best': 718,
#  'take': 719,
#  'boats': 720,
#  'explore': 721,
#  'jungle': 722,
#  'safaris': 723,
#  'canoeing': 724,
#  'bird': 725,
#  'watching': 726,
#  'experiences': 727,
#  'colleges': 728,
#  'universities': 729,
#  'technical': 730,
#  'study': 731,
#  'subjects': 732,
#  'management': 733,
#  'humanities': 734,
#  'medicine': 735,
#  'application': 736,
#  'normally': 737,
#  'require': 738,
#  'recognizing': 739,
#  'images': 740,
#  'making': 741,
#  'finding': 742,
#  'those': 743,
#  'decisions': 744,
#  'regression': 745,
#  'clustering': 746,
#  'forecasting': 747,
#  'uses': 748,
#  'multiple': 749,
#  'layers': 750,
#  'vision': 751,
#  'field': 752,
#  'focuses': 753,
#  'sentiment': 754,
#  'analysis': 755,
#  'question': 756,
#  'answering': 757,
#  'summarization': 758,
#  'estimate': 759,
#  'token': 760,
#  'before': 761,
#  'basic': 762,
#  'if': 763,
#  'receives': 764,
#  'predicted': 765,
#  'short': 766,
#  'memory': 767,
#  'type': 768,
#  'recurrent': 769,
#  'designed': 770,
#  'sequential': 771,
#  'internal': 772,
#  'gates': 773,
#  'manage': 774,
#  'particular': 775,
#  'order': 776,
#  'previous': 777,
#  'after': 778,
#  'starts': 779,
#  'converted': 780,
#  'tokenizer': 781,
#  'embedding': 782,
#  'final': 783,
#  'probabilities': 784,
#  'selected': 785,
#  'original': 786,
#  'repeated': 787,
#  'times': 788,
#  'longer': 789,
#  'until': 790,
#  'required': 791,
#  'presents': 792,
#  'grammatical': 793,
#  'needs': 794,
#  'enough': 795,
#  'useful': 796,
#  'step': 797,
#  'converts': 798,
#  'depending': 799,
#  'method': 800,
#  'subwords': 801,
#  'characters': 802,
#  'assigns': 803,
#  'subword': 804,
#  'problem': 805,
#  'representing': 806,
#  'meaningful': 807,
#  'pieces': 808,
#  'dataset': 809,
#  'news': 810,
#  'articles': 811,
#  'material': 812,
#  'conversations': 813,
#  'expose': 814,
#  'developers': 815,
#  'entrepreneurs': 816,
#  'companies': 817,
#  'working': 818,
#  'easier': 819,
#  'access': 820,
#  'courses': 821,
#  'tutorials': 822,
#  'documentation': 823,
#  'exploring': 824,
#  'fields': 825,
#  'cloud': 826,
#  'computing': 827,
#  'finance': 828,
#  'reach': 829,
#  'customers': 830,
#  'payments': 831,
#  'e': 832,
#  'commerce': 833,
#  'banking': 834,
#  'applications': 835,
#  'protecting': 836,
#  'affect': 837,
#  'ways': 838,
#  'adaptation': 839,
#  'responses': 840,
#  'snow': 841,
#  'begnas': 842,
#  'gosaikunda': 843,
#  'ecological': 844,
#  'clear': 845,
#  'landscape': 846,
#  'peaceful': 847,
#  'varies': 848,
#  'dal': 849,
#  'bhat': 850,
#  'meals': 851,
#  'consists': 852,
#  'lentil': 853,
#  'soup': 854,
#  'side': 855,
#  'dishes': 856,
#  'filled': 857,
#  'chicken': 858,
#  'buffalo': 859,
#  'meat': 860,
#  'ingredients': 861,
#  'spicy': 862,
#  'sauces': 863,
#  'flour': 864,
#  'prepare': 865,
#  'methods': 866,
#  'fermented': 867,
#  'leafy': 868,
#  'vegetable': 869,
#  'eaten': 870,
#  'lentils': 871,
#  'culinary': 872,
#  'folk': 873,
#  'classical': 874,
#  'vary': 875,
#  'literature': 876,
#  'poetry': 877,
#  'novels': 878,
#  'essays': 879,
#  'plays': 880,
#  'writers': 881,
#  'explored': 882,
#  'themes': 883,
#  'everyday': 884,
#  'athletics': 885,
#  'martial': 886,
#  'followers': 887,
#  'school': 888,
#  'levels': 889,
#  'clubs': 890,
#  'competitions': 891,
#  'team': 892,
#  'attracted': 893,
#  'interest': 894,
#  'fans': 895,
#  'sport': 896,
#  'towns': 897,
#  'two': 898,
#  'triangular': 899,
#  'shapes': 900,
#  'moon': 901,
#  'represents': 902,
#  'sovereign': 903,
#  'constitution': 904,
#  'government': 905,
#  'bridges': 906,
#  'trails': 907,
#  'connections': 908,
#  'improving': 909,
#  'hospitals': 910,
#  'medical': 911,
#  'programs': 912,
#  'initiatives': 913,
#  'sanitation': 914,
#  'nutrition': 915,
#  'disease': 916,
#  'prevention': 917,
#  'vaccination': 918,
#  'healthy': 919,
#  'renewable': 920,
#  'energy': 921,
#  'responsible': 922,
#  'place': 923,
#  'weddings': 924,
#  'events': 925,
#  'roles': 926,
#  'welcomed': 927,
#  'warmly': 928,
#  'seen': 929,
#  'climates': 930,
#  'within': 931,
#  'small': 932,
#  'where': 933,
#  'ancient': 934,
#  'smartphones': 935,
#  'internet': 936,
#  'entrepreneurship': 937,
#  'developing': 938,
#  'technologies': 939,
#  'contributing': 940,
#  'solve': 941,
#  'problems': 942,
#  'monitoring': 943,
#  'better': 944,
#  'datasets': 945,
#  'tokenizers': 946,
#  'accessible': 947,
#  'speakers': 948,
#  'project': 949,
#  'context': 950,
#  'provided': 951,
#  'user': 952,
#  'quantity': 953,
#  'corpus': 954,
#  'structures': 955,
#  'carefully': 956,
#  'accuracy': 957,
#  'alone': 958,
#  'does': 959,
#  'not': 960,
#  'show': 961,
#  'works': 962,
#  'unseen': 963,
#  'test': 964,
#  'perplexity': 965,
#  'additional': 966,
#  'occur': 967,
#  'learns': 968,
#  'overfitted': 969,
#  'poor': 970,
#  'repetitive': 971,
#  'given': 972,
#  'dropout': 973,
#  'regularization': 974,
#  'early': 975,
#  'stopping': 976,
#  'appropriate': 977,
#  'size': 978,
#  'sufficient': 979,
#  'kept': 980,
#  'separate': 981,
#  'so': 982,
#  'fairly': 983,
#  'techniques': 984,
#  'always': 985,
#  'selecting': 986,
#  'sample': 987,
#  'control': 988,
#  'random': 989,
#  'conservative': 990,
#  'lower': 991,
#  'higher': 992,
#  'much': 993,
#  'randomness': 994,
#  'grammatically': 995,
#  'incorrect': 996,
#  'meaningless': 997,
#  'sentences': 998,
#  'top': 999,
#  'technique': 1000,
#  ...}

# %%
input_sequence = []

for sentence in text.split('.'): 
    tokenized_sentence = tokenzier.texts_to_sequences([sentence])[0]

    for i in range(1, len(tokenized_sentence)): 
        n_gram = tokenized_sentence[:i+1]
        input_sequence.append(n_gram)

# %%
input_sequence
# Out:
# [[5, 4],
#  [5, 4, 8],
#  [5, 4, 8, 141],
#  [5, 4, 8, 141, 37],
#  [5, 4, 8, 141, 37, 123],
#  [5, 4, 8, 141, 37, 123, 6],
#  [5, 4, 8, 141, 37, 123, 6, 256],
#  [5, 4, 8, 141, 37, 123, 6, 256, 539],
#  [28, 4],
#  [28, 4, 8],
#  [28, 4, 8, 540],
#  [28, 4, 8, 540, 37],
#  [28, 4, 8, 540, 37, 541],
#  [28, 4, 8, 540, 37, 541, 74],
#  [28, 4, 8, 540, 37, 541, 74, 358],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257, 1],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257, 1, 359],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257, 1, 359, 11],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257, 1, 359, 11, 2],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257, 1, 359, 11, 2, 256],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257, 1, 359, 11, 2, 256, 542],
#  [28, 4, 8, 540, 37, 541, 74, 358, 11, 2, 257, 1, 359, 11, 2, 256, 542, 1],
#  [28,
#   4,
#   8,
#   540,
#   37,
#   541,
#   74,
#   358,
#   11,
#   2,
#   257,
#   1,
#   359,
#   11,
#   2,
#   256,
#   542,
#   1,
#   543],
#  [5, 4],
#  [5, 4, 95],
#  [5, 4, 95, 42],
#  [5, 4, 95, 42, 258],
#  [5, 4, 95, 42, 258, 2],
#  [5, 4, 95, 42, 258, 2, 206],
#  [5, 4, 95, 42, 258, 2, 206, 15],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360, 14],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360, 14, 96],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360, 14, 96, 85],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360, 14, 96, 85, 86],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360, 14, 96, 85, 86, 1],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360, 14, 96, 85, 86, 1, 544],
#  [5, 4, 95, 42, 258, 2, 206, 15, 30, 50, 56, 360, 14, 96, 85, 86, 1, 544, 18],
#  [2, 545],
#  [2, 545, 207],
#  [2, 545, 207, 3],
#  [2, 545, 207, 3, 5],
#  [2, 545, 207, 3, 5, 4],
#  [2, 545, 207, 3, 5, 4, 57],
#  [57, 4],
#  [57, 4, 2],
#  [57, 4, 2, 361],
#  [57, 4, 2, 361, 207],
#  [57, 4, 2, 361, 207, 1],
#  [57, 4, 2, 361, 207, 1, 32],
#  [57, 4, 2, 361, 207, 1, 32, 3],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14, 142],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14, 142, 169],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14, 142, 169, 1],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14, 142, 169, 1, 546],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14, 142, 169, 1, 546, 208],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14, 142, 169, 1, 546, 208, 3],
#  [57, 4, 2, 361, 207, 1, 32, 3, 2, 67, 12, 14, 142, 169, 1, 546, 208, 3, 2],
#  [57,
#   4,
#   2,
#   361,
#   207,
#   1,
#   32,
#   3,
#   2,
#   67,
#   12,
#   14,
#   142,
#   169,
#   1,
#   546,
#   208,
#   3,
#   2,
#   37],
#  [2, 57],
#  [2, 57, 87],
#  [2, 57, 87, 107],
#  [2, 57, 87, 107, 57],
#  [2, 57, 87, 107, 57, 259],
#  [2, 57, 87, 107, 57, 259, 1],
#  [2, 57, 87, 107, 57, 259, 1, 170],
#  [2, 87],
#  [2, 87, 4],
#  [2, 87, 4, 108],
#  [2, 87, 4, 108, 15],
#  [2, 87, 4, 108, 15, 30],
#  [2, 87, 4, 108, 15, 30, 124],
#  [2, 87, 4, 108, 15, 30, 124, 260],
#  [2, 87, 4, 108, 15, 30, 124, 260, 20],
#  [2, 87, 4, 108, 15, 30, 124, 260, 20, 58],
#  [2, 87, 4, 108, 15, 30, 124, 260, 20, 58, 22],
#  [2, 87, 4, 108, 15, 30, 124, 260, 20, 58, 22, 171],
#  [2, 87, 4, 108, 15, 30, 124, 260, 20, 58, 22, 171, 1],
#  [2, 87, 4, 108, 15, 30, 124, 260, 20, 58, 22, 171, 1, 14],
#  [2, 87, 4, 108, 15, 30, 124, 260, 20, 58, 22, 171, 1, 14, 86],
#  [5, 24],
#  [5, 24, 8],
#  [5, 24, 8, 362],
#  [5, 24, 8, 362, 61],
#  [5, 24, 8, 362, 61, 209],
#  [2, 37],
#  [2, 37, 4],
#  [2, 37, 4, 143],
#  [2, 37, 4, 143, 547],
#  [2, 37, 4, 143, 547, 261],
#  [2, 37, 4, 143, 547, 261, 548],
#  [2, 37, 4, 143, 547, 261, 548, 144],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2, 125],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2, 125, 33],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2, 125, 33, 2],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2, 125, 33, 2, 172],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2, 125, 33, 2, 172, 33],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2, 125, 33, 2, 172, 33, 1],
#  [2, 37, 4, 143, 547, 261, 548, 144, 262, 75, 2, 125, 33, 2, 172, 33, 1, 2],
#  [2,
#   37,
#   4,
#   143,
#   547,
#   261,
#   548,
#   144,
#   262,
#   75,
#   2,
#   125,
#   33,
#   2,
#   172,
#   33,
#   1,
#   2,
#   80],
#  [2,
#   37,
#   4,
#   143,
#   547,
#   261,
#   548,
#   144,
#   262,
#   75,
#   2,
#   125,
#   33,
#   2,
#   172,
#   33,
#   1,
#   2,
#   80,
#   33],
#  [2, 125],
#  [2, 125, 33],
#  [2, 125, 33, 549],
#  [2, 125, 33, 549, 6],
#  [2, 125, 33, 549, 6, 2],
#  [2, 125, 33, 549, 6, 2, 550],
#  [2, 125, 33, 549, 6, 2, 550, 88],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263, 3],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263, 3, 2],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263, 3, 2, 210],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263, 3, 2, 210, 50],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263, 3, 2, 210, 50, 6],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263, 3, 2, 210, 50, 6, 2],
#  [2, 125, 33, 549, 6, 2, 550, 88, 3, 5, 1, 51, 263, 3, 2, 210, 50, 6, 2, 206],
#  [2, 172],
#  [2, 172, 33],
#  [2, 172, 33, 51],
#  [2, 172, 33, 51, 50],
#  [2, 172, 33, 51, 50, 363],
#  [2, 172, 33, 51, 50, 363, 89],
#  [2, 172, 33, 51, 50, 363, 89, 1],
#  [2, 172, 33, 51, 50, 363, 89, 1, 551],
#  [2, 80],
#  [2, 80, 33],
#  [2, 80, 33, 4],
#  [2, 80, 33, 4, 552],
#  [2, 80, 33, 4, 552, 364],
#  [2, 80, 33, 4, 552, 364, 1],
#  [2, 80, 33, 4, 552, 364, 1, 4],
#  [2, 80, 33, 4, 552, 364, 1, 4, 12],
#  [2, 80, 33, 4, 552, 364, 1, 4, 12, 15],
#  [2, 80, 33, 4, 552, 364, 1, 4, 12, 15, 52],
#  [2, 80, 33, 4, 552, 364, 1, 4, 12, 15, 52, 1],
#  [2, 80, 33, 4, 552, 364, 1, 4, 12, 15, 52, 1, 145],
#  [264, 126],
#  [264, 126, 4],
#  [264, 126, 4, 2],
#  [264, 126, 4, 2, 210],
#  [264, 126, 4, 2, 210, 90],
#  [264, 126, 4, 2, 210, 90, 6],
#  [264, 126, 4, 2, 210, 90, 6, 2],
#  [264, 126, 4, 2, 210, 90, 6, 2, 206],
#  [264, 126, 4, 2, 210, 90, 6, 2, 206, 1],
#  [264, 126, 4, 2, 210, 90, 6, 2, 206, 1, 4],
#  [264, 126, 4, 2, 210, 90, 6, 2, 206, 1, 4, 123],
#  [264, 126, 4, 2, 210, 90, 6, 2, 206, 1, 4, 123, 6],
#  [264, 126, 4, 2, 210, 90, 6, 2, 206, 1, 4, 123, 6, 5],
#  [28, 4],
#  [28, 4, 42],
#  [28, 4, 42, 29],
#  [28, 4, 42, 29, 365],
#  [28, 4, 42, 29, 365, 6],
#  [28, 4, 42, 29, 365, 6, 97],
#  [28, 4, 42, 29, 365, 6, 97, 1],
#  [28, 4, 42, 29, 365, 6, 97, 1, 553],
#  [28, 4, 42, 29, 365, 6, 97, 1, 553, 6],
#  [28, 4, 42, 29, 365, 6, 97, 1, 553, 6, 554],
#  [264, 126],
#  [264, 126, 366],
#  [264, 126, 366, 555],
#  [264, 126, 366, 555, 367],
#  [264, 126, 366, 555, 367, 556],
#  [264, 126, 366, 555, 367, 556, 1],
#  [264, 126, 366, 555, 367, 556, 1, 557],
#  [264, 126, 366, 555, 367, 556, 1, 557, 43],
#  [264, 126, 366, 555, 367, 556, 1, 557, 43, 31],
#  [264, 126, 366, 555, 367, 556, 1, 557, 43, 31, 68],
#  [264, 126, 366, 555, 367, 556, 1, 557, 43, 31, 68, 3],
#  [264, 126, 366, 555, 367, 556, 1, 557, 43, 31, 68, 3, 2],
#  [264, 126, 366, 555, 367, 556, 1, 557, 43, 31, 68, 3, 2, 206],
#  [2, 90],
#  [2, 90, 24],
#  [2, 90, 24, 265],
#  [2, 90, 24, 265, 32],
#  [2, 90, 24, 265, 32, 3],
#  [2, 90, 24, 265, 32, 3, 2],
#  [2, 90, 24, 265, 32, 3, 2, 67],
#  [2, 90, 24, 265, 32, 3, 2, 67, 12],
#  [2, 90, 24, 265, 32, 3, 2, 67, 12, 368],
#  [2, 90, 24, 265, 32, 3, 2, 67, 12, 368, 3],
#  [2, 90, 24, 265, 32, 3, 2, 67, 12, 368, 3, 5],
#  [5, 24],
#  [5, 24, 13],
#  [5, 24, 13, 141],
#  [5, 24, 13, 141, 90],
#  [5, 24, 13, 141, 90, 558],
#  [2, 266],
#  [2, 266, 127],
#  [2, 266, 127, 91],
#  [2, 266, 127, 91, 108],
#  [2, 266, 127, 91, 108, 559],
#  [2, 266, 127, 91, 108, 559, 76],
#  [2, 266, 127, 91, 108, 559, 76, 29],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264, 126],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264, 126, 560],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264, 126, 560, 561],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264, 126, 560, 561, 562],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264, 126, 560, 561, 562, 563],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264, 126, 560, 561, 562, 563, 564],
#  [2, 266, 127, 91, 108, 559, 76, 29, 264, 126, 560, 561, 562, 563, 564, 565],
#  [2,
#   266,
#   127,
#   91,
#   108,
#   559,
#   76,
#   29,
#   264,
#   126,
#   560,
#   561,
#   562,
#   563,
#   564,
#   565,
#   369],
#  [2,
#   266,
#   127,
#   91,
#   108,
#   559,
#   76,
#   29,
#   264,
#   126,
#   560,
#   561,
#   562,
#   563,
#   564,
#   565,
#   369,
#   1],
#  [2,
#   266,
#   127,
#   91,
#   108,
#   559,
#   76,
#   29,
#   264,
#   126,
#   560,
#   561,
#   562,
#   563,
#   564,
#   565,
#   369,
#   1,
#   173],
#  [109, 50],
#  [109, 50, 370],
#  [109, 50, 370, 566],
#  [109, 50, 370, 566, 3],
#  [109, 50, 370, 566, 3, 81],
#  [109, 50, 370, 566, 3, 81, 371],
#  [109, 50, 370, 566, 3, 81, 371, 372],
#  [109, 50, 370, 566, 3, 81, 371, 372, 15],
#  [109, 50, 370, 566, 3, 81, 371, 372, 15, 128],
#  [109, 50, 370, 566, 3, 81, 371, 372, 15, 128, 373],
#  [109, 50, 370, 566, 3, 81, 371, 372, 15, 128, 373, 567],
#  [109, 50, 370, 566, 3, 81, 371, 372, 15, 128, 373, 567, 1],
#  [109, 50, 370, 566, 3, 81, 371, 372, 15, 128, 373, 567, 1, 267],
#  [109, 50, 370, 566, 3, 81, 371, 372, 15, 128, 373, 567, 1, 267, 62],
#  [128, 4],
#  [128, 4, 32],
#  [128, 4, 32, 3],
#  [128, 4, 32, 3, 2],
#  [128, 4, 32, 3, 2, 67],
#  [128, 4, 32, 3, 2, 67, 77],
#  [128, 4, 32, 3, 2, 67, 77, 62],
#  [128, 4, 32, 3, 2, 67, 77, 62, 6],
#  [128, 4, 32, 3, 2, 67, 77, 62, 6, 5],
#  [2, 126],
#  [2, 126, 374],
#  [2, 126, 374, 375],
#  [2, 126, 374, 375, 268],
#  [2, 126, 374, 375, 268, 173],
#  [2, 126, 374, 375, 268, 173, 376],
#  [2, 126, 374, 375, 268, 173, 376, 173],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374, 375],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374, 375, 268],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374, 375, 268, 377],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374, 375, 268, 377, 87],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374, 375, 268, 377, 87, 268],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374, 375, 268, 377, 87, 268, 1],
#  [2, 126, 374, 375, 268, 173, 376, 173, 374, 375, 268, 377, 87, 268, 1, 369],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376,
#   9],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376,
#   9,
#   174],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376,
#   9,
#   174,
#   2],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376,
#   9,
#   174,
#   2,
#   95],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376,
#   9,
#   174,
#   2,
#   95,
#   42],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376,
#   9,
#   174,
#   2,
#   95,
#   42,
#   128],
#  [2,
#   126,
#   374,
#   375,
#   268,
#   173,
#   376,
#   173,
#   374,
#   375,
#   268,
#   377,
#   87,
#   268,
#   1,
#   369,
#   376,
#   9,
#   174,
#   2,
#   95,
#   42,
#   128,
#   269],
#  [378, 10],
#  [378, 10, 175],
#  [378, 10, 175, 90],
#  [378, 10, 175, 90, 211],
#  [378, 10, 175, 90, 211, 89],
#  [378, 10, 175, 90, 211, 89, 69],
#  [378, 10, 175, 90, 211, 89, 69, 146],
#  [378, 10, 175, 90, 211, 89, 69, 146, 270],
#  [378, 10, 175, 90, 211, 89, 69, 146, 270, 1],
#  [378, 10, 175, 90, 211, 89, 69, 146, 270, 1, 49],
#  [378, 10, 175, 90, 211, 89, 69, 146, 270, 1, 49, 212],
#  [378, 10, 175, 90, 211, 89, 69, 146, 270, 1, 49, 212, 129],
#  [378, 10, 175, 90, 211, 89, 69, 146, 270, 1, 49, 212, 129, 44],
#  [378, 10, 175, 90, 211, 89, 69, 146, 270, 1, 49, 212, 129, 44, 568],
#  [5, 4],
#  [5, 4, 38],
#  [5, 4, 38, 213],
#  [5, 4, 38, 213, 6],
#  [5, 4, 38, 213, 6, 69],
#  [5, 4, 38, 213, 6, 69, 1],
#  [5, 4, 38, 213, 6, 69, 1, 110],
#  [5, 4, 38, 213, 6, 69, 1, 110, 98],
#  [13, 69],
#  [13, 69, 569],
#  [13, 69, 569, 6],
#  [13, 69, 569, 6, 2],
#  [13, 69, 569, 6, 2, 125],
#  [13, 69, 569, 6, 2, 125, 33],
#  [13, 69, 569, 6, 2, 125, 33, 1],
#  [13, 69, 569, 6, 2, 125, 33, 1, 570],
#  [13, 69, 569, 6, 2, 125, 33, 1, 570, 571],
#  [13, 69, 569, 6, 2, 125, 33, 1, 570, 571, 2],
#  [13, 69, 569, 6, 2, 125, 33, 1, 570, 571, 2, 379],
#  [13, 69, 569, 6, 2, 125, 33, 1, 570, 571, 2, 379, 176],
#  [2, 144],
#  [2, 144, 177],
#  [2, 144, 177, 82],
#  [2, 144, 177, 82, 127],
#  [2, 144, 177, 82, 127, 2],
#  [2, 144, 177, 82, 127, 2, 380],
#  [2, 144, 177, 82, 127, 2, 380, 572],
#  [2, 144, 177, 82, 127, 2, 380, 572, 1],
#  [2, 144, 177, 82, 127, 2, 380, 572, 1, 573],
#  [2, 144, 177, 82, 127, 2, 380, 572, 1, 573, 177],
#  [2, 144, 177, 82, 127, 2, 380, 572, 1, 573, 177, 82],
#  [69, 9],
#  [69, 9, 12],
#  [69, 9, 12, 15],
#  [69, 9, 12, 15, 52],
#  [69, 9, 12, 15, 52, 574],
#  [69, 9, 12, 15, 52, 574, 110],
#  [69, 9, 12, 15, 52, 574, 110, 575],
#  [69, 9, 12, 15, 52, 574, 110, 575, 214],
#  [69, 9, 12, 15, 52, 574, 110, 575, 214, 53],
#  [69, 9, 12, 15, 52, 574, 110, 575, 214, 53, 1],
#  [69, 9, 12, 15, 52, 574, 110, 575, 214, 53, 1, 130],
#  [5, 24],
#  [5, 24, 8],
#  [5, 24, 8, 576],
#  [5, 24, 8, 576, 577],
#  [5, 24, 8, 576, 577, 3],
#  [5, 24, 8, 576, 577, 3, 215],
#  [5, 24, 8, 576, 577, 3, 215, 1],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216, 178],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216, 178, 3],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216, 178, 3, 30],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216, 178, 3, 30, 61],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216, 178, 3, 30, 61, 209],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216, 178, 3, 30, 61, 209, 1],
#  [5, 24, 8, 576, 577, 3, 215, 1, 216, 178, 3, 30, 61, 209, 1, 271],
#  [2, 37],
#  [2, 37, 51],
#  [2, 37, 51, 89],
#  [2, 37, 51, 89, 578],
#  [2, 37, 51, 89, 578, 381],
#  [2, 37, 51, 89, 578, 381, 50],
#  [2, 37, 51, 89, 578, 381, 50, 1],
#  [2, 37, 51, 89, 578, 381, 50, 1, 36],
#  [2, 37, 51, 89, 578, 381, 50, 1, 36, 130],
#  [31, 382],
#  [31, 382, 3],
#  [31, 382, 3, 383],
#  [31, 382, 3, 383, 579],
#  [31, 382, 3, 383, 579, 580],
#  [31, 382, 3, 383, 579, 580, 1],
#  [31, 382, 3, 383, 579, 580, 1, 215],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10, 39],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10, 39, 179],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10, 39, 179, 6],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10, 39, 179, 6, 31],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10, 39, 179, 6, 31, 68],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10, 39, 179, 6, 31, 68, 3],
#  [31, 382, 3, 383, 579, 580, 1, 215, 10, 39, 179, 6, 31, 68, 3, 5],
#  [272, 99],
#  [272, 99, 217],
#  [272, 99, 217, 4],
#  [272, 99, 217, 4, 32],
#  [272, 99, 217, 4, 32, 3],
#  [272, 99, 217, 4, 32, 3, 2],
#  [272, 99, 217, 4, 32, 3, 2, 67],
#  [272, 99, 217, 4, 32, 3, 2, 67, 108],
#  [272, 99, 217, 4, 32, 3, 2, 67, 108, 384],
#  [272, 99, 217, 4, 32, 3, 2, 67, 108, 384, 54],
#  [272, 99, 217, 4, 32, 3, 2, 67, 108, 384, 54, 6],
#  [272, 99, 217, 4, 32, 3, 2, 67, 108, 384, 54, 6, 5],
#  [28, 4],
#  [28, 4, 42],
#  [28, 4, 42, 15],
#  [28, 4, 42, 15, 30],
#  [28, 4, 42, 15, 30, 180],
#  [28, 4, 42, 15, 30, 180, 1],
#  [28, 4, 42, 15, 30, 180, 1, 56],
#  [28, 4, 42, 15, 30, 180, 1, 56, 111],
#  [81, 10],
#  [81, 10, 581],
#  [81, 10, 581, 216],
#  [81, 10, 581, 216, 76],
#  [81, 10, 581, 216, 76, 29],
#  [81, 10, 581, 216, 76, 29, 2],
#  [81, 10, 581, 216, 76, 29, 2, 582],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32, 583],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32, 583, 584],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32, 583, 584, 585],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32, 583, 584, 585, 586],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32, 583, 584, 585, 586, 587],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32, 583, 584, 585, 586, 587, 588],
#  [81, 10, 581, 216, 76, 29, 2, 582, 32, 583, 584, 585, 586, 587, 588, 589],
#  [81,
#   10,
#   581,
#   216,
#   76,
#   29,
#   2,
#   582,
#   32,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590],
#  [81,
#   10,
#   581,
#   216,
#   76,
#   29,
#   2,
#   582,
#   32,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590,
#   1],
#  [81,
#   10,
#   581,
#   216,
#   76,
#   29,
#   2,
#   582,
#   32,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590,
#   1,
#   13],
#  [81,
#   10,
#   581,
#   216,
#   76,
#   29,
#   2,
#   582,
#   32,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590,
#   1,
#   13,
#   382],
#  [81,
#   10,
#   581,
#   216,
#   76,
#   29,
#   2,
#   582,
#   32,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590,
#   1,
#   13,
#   382,
#   3],
#  [81,
#   10,
#   581,
#   216,
#   76,
#   29,
#   2,
#   582,
#   32,
#   583,
#   584,
#   585,
#   586,
#   587,
#   588,
#   589,
#   590,
#   1,
#   13,
#   382,
#   3,
#   383],
#  [365, 99],
#  [365, 99, 217],
#  [365, 99, 217, 4],
#  [365, 99, 217, 4, 123],
#  [365, 99, 217, 4, 123, 6],
#  [365, 99, 217, 4, 123, 6, 2],
#  [365, 99, 217, 4, 123, 6, 2, 126],
#  [365, 99, 217, 4, 123, 6, 2, 126, 33],
#  [28, 51],
#  [28, 51, 131],
#  [28, 51, 131, 50],
#  [28, 51, 131, 50, 273],
#  [28, 51, 131, 50, 273, 363],
#  [28, 51, 131, 50, 273, 363, 89],
#  [28, 51, 131, 50, 273, 363, 89, 1],
#  [28, 51, 131, 50, 273, 363, 89, 1, 146],
#  [2, 217],
#  [2, 217, 4],
#  [2, 217, 4, 274],
#  [2, 217, 4, 274, 11],
#  [2, 217, 4, 274, 11, 591],
#  [2, 217, 4, 274, 11, 591, 215],
#  [2, 217, 4, 274, 11, 591, 215, 1],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216, 100],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216, 100, 23],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216, 100, 23, 592],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216, 100, 23, 592, 11],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216, 100, 23, 592, 11, 131],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216, 100, 23, 592, 11, 131, 218],
#  [2, 217, 4, 274, 11, 591, 215, 1, 216, 100, 23, 592, 11, 131, 218, 132],
#  [5, 24],
#  [5, 24, 13],
#  [5, 24, 13, 99],
#  [5, 24, 13, 99, 593],
#  [5, 24, 13, 99, 593, 1],
#  [5, 24, 13, 99, 593, 1, 181],
#  [5, 24, 13, 99, 593, 1, 181, 54],
#  [109, 384],
#  [109, 384, 54],
#  [109, 384, 54, 92],
#  [109, 384, 54, 92, 594],
#  [109, 384, 54, 92, 594, 595],
#  [109, 384, 54, 92, 594, 595, 89],
#  [109, 384, 54, 92, 594, 595, 89, 180],
#  [109, 384, 54, 92, 594, 595, 89, 180, 1],
#  [109, 384, 54, 92, 594, 595, 89, 180, 1, 56],
#  [109, 384, 54, 92, 594, 595, 89, 180, 1, 56, 211],
#  [181, 4],
#  [181, 4, 12],
#  [181, 4, 12, 178],
#  [181, 4, 12, 178, 5],
#  [181, 4, 12, 178, 5, 51],
#  [181, 4, 12, 178, 5, 51, 13],
#  [181, 4, 12, 178, 5, 51, 13, 219],
#  [181, 4, 12, 178, 5, 51, 13, 219, 130],
#  [181, 4, 12, 178, 5, 51, 13, 219, 130, 100],
#  [181, 4, 12, 178, 5, 51, 13, 219, 130, 100, 596],
#  [181, 4, 12, 178, 5, 51, 13, 219, 130, 100, 596, 182],
#  [181, 4, 12, 178, 5, 51, 13, 219, 130, 100, 596, 182, 275],
#  [181, 4, 12, 178, 5, 51, 13, 219, 130, 100, 596, 182, 275, 385],
#  [5, 4],
#  [5, 4, 597],
#  [5, 4, 597, 61],
#  [18, 43],
#  [18, 43, 13],
#  [18, 43, 13, 386],
#  [18, 43, 13, 386, 387],
#  [18, 43, 13, 386, 387, 1],
#  [18, 43, 13, 386, 387, 1, 7],
#  [18, 43, 13, 386, 387, 1, 7, 183],
#  [18, 43, 13, 386, 387, 1, 7, 183, 6],
#  [18, 43, 13, 386, 387, 1, 7, 183, 6, 31],
#  [18, 43, 13, 386, 387, 1, 7, 183, 6, 31, 68],
#  [18, 43, 13, 386, 387, 1, 7, 183, 6, 31, 68, 3],
#  [18, 43, 13, 386, 387, 1, 7, 183, 6, 31, 68, 3, 2],
#  [18, 43, 13, 386, 387, 1, 7, 183, 6, 31, 68, 3, 2, 37],
#  [147, 21],
#  [147, 21, 24],
#  [147, 21, 24, 30],
#  [147, 21, 24, 30, 63],
#  [147, 21, 24, 30, 63, 25],
#  [147, 21, 24, 30, 63, 25, 45],
#  [147, 21, 24, 30, 63, 25, 45, 26],
#  [147, 21, 24, 30, 63, 25, 45, 26, 78],
#  [147, 21, 24, 30, 63, 25, 45, 26, 78, 46],
#  [147, 21, 24, 30, 63, 25, 45, 26, 78, 46, 22],
#  [147, 21, 24, 30, 63, 25, 45, 26, 78, 46, 22, 1],
#  [147, 21, 24, 30, 63, 25, 45, 26, 78, 46, 22, 1, 14],
#  [147, 21, 24, 30, 63, 25, 45, 26, 78, 46, 22, 1, 14, 59],
#  [14, 96],
#  [14, 96, 4],
#  [14, 96, 4, 32],
#  [14, 96, 4, 32, 3],
#  [14, 96, 4, 32, 3, 2],
#  [14, 96, 4, 32, 3, 2, 12],
#  [14, 96, 4, 32, 3, 2, 12, 598],
#  [14, 96, 4, 32, 3, 2, 12, 598, 3],
#  [14, 96, 4, 32, 3, 2, 12, 598, 3, 5],
#  [97, 4],
#  [97, 4, 2],
#  [97, 4, 2, 599],
#  [97, 4, 2, 599, 19],
#  [97, 4, 2, 599, 19, 3],
#  [97, 4, 2, 599, 19, 3, 5],
#  [276, 13],
#  [276, 13, 36],
#  [276, 13, 36, 45],
#  [276, 13, 36, 45, 9],
#  [276, 13, 36, 45, 9, 600],
#  [276, 13, 36, 45, 9, 600, 133],
#  [276, 13, 36, 45, 9, 600, 133, 2],
#  [276, 13, 36, 45, 9, 600, 133, 2, 37],
#  [45, 76],
#  [45, 76, 29],
#  [45, 76, 29, 601],
#  [45, 76, 29, 601, 602],
#  [45, 76, 29, 601, 602, 148],
#  [45, 76, 29, 601, 602, 148, 101],
#  [45, 76, 29, 601, 602, 148, 101, 5],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112, 604],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112, 604, 113],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112, 604, 113, 184],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112, 604, 113, 184, 149],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112, 604, 113, 184, 149, 1],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112, 604, 113, 184, 149, 1, 13],
#  [45, 76, 29, 601, 602, 148, 101, 5, 603, 112, 604, 113, 184, 149, 1, 13, 36],
#  [45,
#   76,
#   29,
#   601,
#   602,
#   148,
#   101,
#   5,
#   603,
#   112,
#   604,
#   113,
#   184,
#   149,
#   1,
#   13,
#   36,
#   45],
#  [45,
#   76,
#   29,
#   601,
#   602,
#   148,
#   101,
#   5,
#   603,
#   112,
#   604,
#   113,
#   184,
#   149,
#   1,
#   13,
#   36,
#   45,
#   9],
#  [45,
#   76,
#   29,
#   601,
#   602,
#   148,
#   101,
#   5,
#   603,
#   112,
#   604,
#   113,
#   184,
#   149,
#   1,
#   13,
#   36,
#   45,
#   9,
#   114],
#  [45,
#   76,
#   29,
#   601,
#   602,
#   148,
#   101,
#   5,
#   603,
#   112,
#   604,
#   113,
#   184,
#   149,
#   1,
#   13,
#   36,
#   45,
#   9,
#   114,
#   74],
#  [45,
#   76,
#   29,
#   601,
#   602,
#   148,
#   101,
#   5,
#   603,
#   112,
#   604,
#   113,
#   184,
#   149,
#   1,
#   13,
#   36,
#   45,
#   9,
#   114,
#   74,
#   31],
#  [45,
#   76,
#   29,
#   601,
#   602,
#   148,
#   101,
#   5,
#   603,
#   112,
#   604,
#   113,
#   184,
#   149,
#   1,
#   13,
#   36,
#   45,
#   9,
#   114,
#   74,
#   31,
#   7],
#  [5, 4],
#  [5, 4, 274],
#  [5, 4, 274, 11],
#  [5, 4, 274, 11, 18],
#  [5, 4, 274, 11, 18, 43],
#  [5, 4, 274, 11, 18, 43, 31],
#  [5, 4, 274, 11, 18, 43, 31, 70],
#  [5, 4, 274, 11, 18, 43, 31, 70, 605],
#  [606, 1],
#  [606, 1, 607],
#  [606, 1, 607, 23],
#  [606, 1, 607, 23, 8],
#  [606, 1, 607, 23, 8, 182],
#  [606, 1, 607, 23, 8, 182, 134],
#  [606, 1, 607, 23, 8, 182, 134, 6],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36, 70],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36, 70, 7],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36, 70, 7, 76],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36, 70, 7, 76, 29],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36, 70, 7, 76, 29, 608],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36, 70, 7, 76, 29, 608, 609],
#  [606, 1, 607, 23, 8, 182, 134, 6, 2, 37, 135, 36, 70, 7, 76, 29, 608, 609, 1],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277,
#   7],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277,
#   7,
#   9],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277,
#   7,
#   9,
#   38],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277,
#   7,
#   9,
#   38,
#   88],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277,
#   7,
#   9,
#   38,
#   88,
#   3],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277,
#   7,
#   9,
#   38,
#   88,
#   3,
#   97],
#  [606,
#   1,
#   607,
#   23,
#   8,
#   182,
#   134,
#   6,
#   2,
#   37,
#   135,
#   36,
#   70,
#   7,
#   76,
#   29,
#   608,
#   609,
#   1,
#   277,
#   7,
#   9,
#   38,
#   88,
#   3,
#   97,
#   150],
#  [70, 96],
#  [70, 96, 610],
#  [70, 96, 610, 11],
#  [70, 96, 610, 11, 2],
#  [70, 96, 610, 11, 2, 14],
#  [70, 96, 610, 11, 2, 14, 388],
#  [70, 96, 610, 11, 2, 14, 388, 3],
#  [70, 96, 610, 11, 2, 14, 388, 3, 5],
#  [5, 611],
#  [5, 611, 13],
#  [5, 611, 13, 22],
#  [5, 611, 13, 22, 278],
#  [5, 611, 13, 22, 278, 2],
#  [5, 611, 13, 22, 278, 2, 389],
#  [279, 280],
#  [279, 280, 281],
#  [279, 280, 281, 612],
#  [279, 280, 281, 612, 282],
#  [279, 280, 281, 612, 282, 390],
#  [279, 280, 281, 612, 282, 390, 613],
#  [279, 280, 281, 612, 282, 390, 613, 614],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615, 616],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615, 616, 617],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615, 616, 617, 618],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615, 616, 617, 618, 1],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615, 616, 617, 618, 1, 13],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615, 616, 617, 618, 1, 13, 49],
#  [279, 280, 281, 612, 282, 390, 613, 614, 615, 616, 617, 618, 1, 13, 49, 22],
#  [279,
#   280,
#   281,
#   612,
#   282,
#   390,
#   613,
#   614,
#   615,
#   616,
#   617,
#   618,
#   1,
#   13,
#   49,
#   22,
#   9],
#  [279,
#   280,
#   281,
#   612,
#   282,
#   390,
#   613,
#   614,
#   615,
#   616,
#   617,
#   618,
#   1,
#   13,
#   49,
#   22,
#   9,
#   283],
#  [279,
#   280,
#   281,
#   612,
#   282,
#   390,
#   613,
#   614,
#   615,
#   616,
#   617,
#   618,
#   1,
#   13,
#   49,
#   22,
#   9,
#   283,
#   74],
#  [279,
#   280,
#   281,
#   612,
#   282,
#   390,
#   613,
#   614,
#   615,
#   616,
#   617,
#   618,
#   1,
#   13,
#   49,
#   22,
#   9,
#   283,
#   74,
#   31],
#  [279,
#   280,
#   281,
#   612,
#   282,
#   390,
#   613,
#   614,
#   615,
#   616,
#   617,
#   618,
#   1,
#   13,
#   49,
#   22,
#   9,
#   283,
#   74,
#   31,
#   7],
#  [279, 4],
#  [279, 4, 32],
#  [279, 4, 32, 3],
#  [279, 4, 32, 3, 2],
#  [279, 4, 32, 3, 2, 619],
#  [279, 4, 32, 3, 2, 619, 22],
#  [279, 4, 32, 3, 2, 619, 22, 6],
#  [279, 4, 32, 3, 2, 619, 22, 6, 5],
#  [129, 279],
#  [129, 279, 391],
#  [129, 279, 391, 185],
#  [129, 279, 391, 185, 392],
#  [129, 279, 391, 185, 392, 284],
#  [129, 279, 391, 185, 392, 284, 620],
#  [129, 279, 391, 185, 392, 284, 620, 621],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1, 622],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1, 622, 43],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1, 622, 43, 623],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1, 622, 43, 623, 1],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1, 622, 43, 623, 1, 624],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1, 622, 43, 623, 1, 624, 393],
#  [129, 279, 391, 185, 392, 284, 620, 621, 1, 622, 43, 623, 1, 624, 393, 16],
#  [129,
#   279,
#   391,
#   185,
#   392,
#   284,
#   620,
#   621,
#   1,
#   622,
#   43,
#   623,
#   1,
#   624,
#   393,
#   16,
#   625],
#  [2, 93],
#  [2, 93, 4],
#  [2, 93, 4, 34],
#  [2, 93, 4, 34, 16],
#  [2, 93, 4, 34, 16, 186],
#  [2, 93, 4, 34, 16, 186, 25],
#  [2, 93, 4, 34, 16, 186, 25, 220],
#  [2, 93, 4, 34, 16, 186, 25, 220, 1],
#  [2, 93, 4, 34, 16, 186, 25, 220, 1, 14],
#  [2, 93, 4, 34, 16, 186, 25, 220, 1, 14, 62],
#  [280, 4],
#  [280, 4, 94],
#  [280, 4, 94, 144],
#  [280, 4, 94, 144, 93],
#  [280, 4, 94, 144, 93, 6],
#  [280, 4, 94, 144, 93, 6, 5],
#  [28, 4],
#  [28, 4, 185],
#  [28, 4, 185, 42],
#  [28, 4, 185, 42, 29],
#  [28, 4, 185, 42, 29, 2],
#  [28, 4, 185, 42, 29, 2, 93],
#  [28, 4, 185, 42, 29, 2, 93, 3],
#  [28, 4, 185, 42, 29, 2, 93, 3, 626],
#  [129, 280],
#  [129, 280, 18],
#  [129, 280, 18, 627],
#  [129, 280, 18, 627, 44],
#  [129, 280, 18, 627, 44, 628],
#  [129, 280, 18, 627, 44, 628, 629],
#  [129, 280, 18, 627, 44, 628, 629, 630],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151, 631],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151, 631, 136],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151, 631, 136, 1],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151, 631, 136, 1, 394],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151, 631, 136, 1, 394, 6],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151, 631, 136, 1, 394, 6, 14],
#  [129, 280, 18, 627, 44, 628, 629, 630, 151, 631, 136, 1, 394, 6, 14, 62],
#  [632, 1],
#  [632, 1, 633],
#  [632, 1, 633, 9],
#  [632, 1, 633, 9, 77],
#  [632, 1, 633, 9, 77, 20],
#  [632, 1, 633, 9, 77, 20, 62],
#  [632, 1, 633, 9, 77, 20, 62, 129],
#  [632, 1, 633, 9, 77, 20, 62, 129, 2],
#  [632, 1, 633, 9, 77, 20, 62, 129, 2, 93],
#  [281, 4],
#  [281, 4, 42],
#  [281, 4, 42, 29],
#  [281, 4, 42, 29, 2],
#  [281, 4, 42, 29, 2, 93],
#  [281, 4, 42, 29, 2, 93, 3],
#  [281, 4, 42, 29, 2, 93, 3, 395],
#  [18, 634],
#  [18, 634, 281],
#  [18, 634, 281, 74],
#  [18, 634, 281, 74, 635],
#  [18, 634, 281, 74, 635, 16],
#  [18, 634, 281, 74, 635, 16, 395],
#  [18, 634, 281, 74, 635, 16, 395, 636],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1, 186],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1, 186, 1],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1, 186, 1, 638],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1, 186, 1, 638, 31],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1, 186, 1, 638, 31, 221],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1, 186, 1, 638, 31, 221, 1],
#  [18, 634, 281, 74, 635, 16, 395, 636, 637, 1, 186, 1, 638, 31, 221, 1, 14],
#  [18,
#   634,
#   281,
#   74,
#   635,
#   16,
#   395,
#   636,
#   637,
#   1,
#   186,
#   1,
#   638,
#   31,
#   221,
#   1,
#   14,
#   62],
#  [2, 93],
#  [2, 93, 4],
#  [2, 93, 4, 283],
#  [2, 93, 4, 283, 6],
#  [2, 93, 4, 283, 6, 13],
#  [2, 93, 4, 283, 6, 13, 68],
#  [2, 93, 4, 283, 6, 13, 68, 3],
#  [2, 93, 4, 283, 6, 13, 68, 3, 5],
#  [282, 4],
#  [282, 4, 17],
#  [282, 4, 17, 12],
#  [282, 4, 17, 12, 93],
#  [282, 4, 17, 12, 93, 102],
#  [282, 4, 17, 12, 93, 102, 6],
#  [282, 4, 17, 12, 93, 102, 6, 2],
#  [282, 4, 17, 12, 93, 102, 6, 2, 80],
#  [282, 4, 17, 12, 93, 102, 6, 2, 80, 33],
#  [18, 639],
#  [18, 639, 2],
#  [18, 639, 2, 396],
#  [18, 639, 2, 396, 1],
#  [18, 639, 2, 396, 1, 392],
#  [18, 639, 2, 396, 1, 392, 640],
#  [18, 639, 2, 396, 1, 392, 640, 69],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641, 1],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641, 1, 36],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641, 1, 36, 110],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641, 1, 36, 110, 642],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641, 1, 36, 110, 642, 129],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641, 1, 36, 110, 642, 129, 2],
#  [18, 639, 2, 396, 1, 392, 640, 69, 641, 1, 36, 110, 642, 129, 2, 93],
#  [282, 24],
#  [282, 24, 397],
#  [282, 24, 397, 14],
#  [282, 24, 397, 14, 1],
#  [282, 24, 397, 14, 1, 70],
#  [282, 24, 397, 14, 1, 70, 643],
#  [282, 24, 397, 14, 1, 70, 643, 15],
#  [282, 24, 397, 14, 1, 70, 643, 15, 13],
#  [282, 24, 397, 14, 1, 70, 643, 15, 13, 7],
#  [398, 4],
#  [398, 4, 32],
#  [398, 4, 32, 3],
#  [398, 4, 32, 3, 2],
#  [398, 4, 32, 3, 2, 67],
#  [398, 4, 32, 3, 2, 67, 12],
#  [398, 4, 32, 3, 2, 67, 12, 85],
#  [398, 4, 32, 3, 2, 67, 12, 85, 1],
#  [398, 4, 32, 3, 2, 67, 12, 85, 1, 70],
#  [398, 4, 32, 3, 2, 67, 12, 85, 1, 70, 285],
#  [398, 4, 32, 3, 2, 67, 12, 85, 1, 70, 285, 6],
#  [398, 4, 32, 3, 2, 67, 12, 85, 1, 70, 285, 6, 5],
#  [28, 4],
#  [28, 4, 187],
#  [28, 4, 187, 644],
#  [28, 4, 187, 644, 29],
#  [28, 4, 187, 644, 29, 2],
#  [28, 4, 187, 644, 29, 2, 645],
#  [28, 4, 187, 644, 29, 2, 645, 3],
#  [28, 4, 187, 644, 29, 2, 645, 3, 646],
#  [28, 4, 187, 644, 29, 2, 645, 3, 646, 390],
#  [18, 43],
#  [18, 43, 5],
#  [18, 43, 5, 1],
#  [18, 43, 5, 1, 13],
#  [18, 43, 5, 1, 13, 36],
#  [18, 43, 5, 1, 13, 36, 286],
#  [18, 43, 5, 1, 13, 36, 286, 287],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398, 15],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398, 15, 70],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398, 15, 70, 14],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398, 15, 70, 14, 85],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398, 15, 70, 14, 85, 1],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398, 15, 70, 14, 85, 1, 169],
#  [18, 43, 5, 1, 13, 36, 286, 287, 398, 15, 70, 14, 85, 1, 169, 647],
#  [57, 87],
#  [57, 87, 51],
#  [57, 87, 51, 13],
#  [57, 87, 51, 13, 85],
#  [57, 87, 51, 13, 85, 1],
#  [57, 87, 51, 13, 85, 1, 14],
#  [57, 87, 51, 13, 85, 1, 14, 285],
#  [57, 188],
#  [57, 188, 189],
#  [57, 188, 189, 288],
#  [57, 188, 189, 288, 188],
#  [57, 188, 189, 288, 188, 189],
#  [57, 188, 189, 288, 188, 189, 170],
#  [57, 188, 189, 288, 188, 189, 170, 188],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189, 399],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189, 399, 289],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189, 399, 289, 400],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189, 399, 289, 400, 1],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189, 399, 289, 400, 1, 290],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189, 399, 289, 400, 1, 290, 9],
#  [57, 188, 189, 288, 188, 189, 170, 188, 189, 399, 289, 400, 1, 290, 9, 174],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2,
#   95],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2,
#   95,
#   42],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2,
#   95,
#   42,
#   86],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2,
#   95,
#   42,
#   86,
#   285],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2,
#   95,
#   42,
#   86,
#   285,
#   6],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2,
#   95,
#   42,
#   86,
#   285,
#   6,
#   2],
#  [57,
#   188,
#   189,
#   288,
#   188,
#   189,
#   170,
#   188,
#   189,
#   399,
#   289,
#   400,
#   1,
#   290,
#   9,
#   174,
#   2,
#   95,
#   42,
#   86,
#   285,
#   6,
#   2,
#   87],
#  [399, 289],
#  [399, 289, 4],
#  [399, 289, 4, 32],
#  [399, 289, 4, 32, 3],
#  [399, 289, 4, 32, 3, 2],
#  [399, 289, 4, 32, 3, 2, 67],
#  [399, 289, 4, 32, 3, 2, 67, 12],
#  [399, 289, 4, 32, 3, 2, 67, 12, 401],
#  [399, 289, 4, 32, 3, 2, 67, 12, 401, 124],
#  [399, 289, 4, 32, 3, 2, 67, 12, 401, 124, 6],
#  [399, 289, 4, 32, 3, 2, 67, 12, 401, 124, 6, 5],
#  [28, 4],
#  [28, 4, 123],
#  [28, 4, 123, 6],
#  [28, 4, 123, 6, 57],
#  [28, 4, 123, 6, 57, 648],
#  [28, 4, 123, 6, 57, 648, 2],
#  [28, 4, 123, 6, 57, 648, 2, 649],
#  [28, 4, 123, 6, 57, 648, 2, 649, 177],
#  [2, 289],
#  [2, 289, 4],
#  [2, 289, 4, 650],
#  [2, 289, 4, 650, 11],
#  [2, 289, 4, 650, 11, 651],
#  [2, 289, 4, 650, 11, 651, 652],
#  [2, 289, 4, 650, 11, 651, 652, 1],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366, 13],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366, 13, 653],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366, 13, 653, 43],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366, 13, 653, 43, 5],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366, 13, 653, 43, 5, 1],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366, 13, 653, 43, 5, 1, 36],
#  [2, 289, 4, 650, 11, 651, 652, 1, 366, 13, 653, 43, 5, 1, 36, 286],
#  [400, 4],
#  [400, 4, 17],
#  [400, 4, 17, 12],
#  [400, 4, 17, 12, 152],
#  [400, 4, 17, 12, 152, 1],
#  [400, 4, 17, 12, 152, 1, 70],
#  [400, 4, 17, 12, 152, 1, 70, 402],
#  [400, 4, 17, 12, 152, 1, 70, 402, 123],
#  [400, 4, 17, 12, 152, 1, 70, 402, 123, 64],
#  [400, 4, 17, 12, 152, 1, 70, 402, 123, 64, 8],
#  [400, 4, 17, 12, 152, 1, 70, 402, 123, 64, 8, 291],
#  [400, 4, 17, 12, 152, 1, 70, 402, 123, 64, 8, 291, 6],
#  [400, 4, 17, 12, 152, 1, 70, 402, 123, 64, 8, 291, 6, 57],
#  [2, 402],
#  [2, 402, 51],
#  [2, 402, 51, 8],
#  [2, 402, 51, 8, 292],
#  [2, 402, 51, 8, 292, 403],
#  [2, 402, 51, 8, 292, 403, 1],
#  [2, 402, 51, 8, 292, 403, 1, 91],
#  [2, 402, 51, 8, 292, 403, 1, 91, 124],
#  [2, 402, 51, 8, 292, 403, 1, 91, 124, 1],
#  [2, 402, 51, 8, 292, 403, 1, 91, 124, 1, 654],
#  [28, 38],
#  [28, 38, 293],
#  [28, 38, 293, 8],
#  [28, 38, 293, 8, 655],
#  [28, 38, 293, 8, 655, 656],
#  [28, 38, 293, 8, 655, 656, 3],
#  [28, 38, 293, 8, 655, 656, 3, 57],
#  [28, 38, 293, 8, 655, 656, 3, 57, 87],
#  [290, 4],
#  [290, 4, 32],
#  [290, 4, 32, 3],
#  [290, 4, 32, 3, 2],
#  [290, 4, 32, 3, 2, 361],
#  [290, 4, 32, 3, 2, 361, 1],
#  [290, 4, 32, 3, 2, 361, 1, 67],
#  [290, 4, 32, 3, 2, 361, 1, 67, 108],
#  [290, 4, 32, 3, 2, 361, 1, 67, 108, 152],
#  [290, 4, 32, 3, 2, 361, 1, 67, 108, 152, 657],
#  [290, 4, 32, 3, 2, 361, 1, 67, 108, 152, 657, 6],
#  [290, 4, 32, 3, 2, 361, 1, 67, 108, 152, 657, 6, 5],
#  [2, 137],
#  [2, 137, 258],
#  [2, 137, 258, 2],
#  [2, 137, 258, 2, 403],
#  [2, 137, 258, 2, 403, 51],
#  [2, 137, 258, 2, 403, 51, 270],
#  [2, 137, 258, 2, 403, 51, 270, 404],
#  [2, 137, 258, 2, 403, 51, 270, 404, 405],
#  [2, 137, 258, 2, 403, 51, 270, 404, 405, 1],
#  [2, 137, 258, 2, 403, 51, 270, 404, 405, 1, 14],
#  [2, 137, 258, 2, 403, 51, 270, 404, 405, 1, 14, 208],
#  [13, 152],
#  [13, 152, 81],
#  [13, 152, 81, 1],
#  [13, 152, 81, 1, 406],
#  [13, 152, 81, 1, 406, 287],
#  [13, 152, 81, 1, 406, 287, 290],
#  [13, 152, 81, 1, 406, 287, 290, 278],
#  [13, 152, 81, 1, 406, 287, 290, 278, 2],
#  [13, 152, 81, 1, 406, 287, 290, 278, 2, 389],
#  [170, 4],
#  [170, 4, 8],
#  [170, 4, 8, 658],
#  [170, 4, 8, 658, 207],
#  [170, 4, 8, 658, 207, 6],
#  [170, 4, 8, 658, 207, 6, 57],
#  [170, 4, 8, 658, 207, 6, 57, 87],
#  [28, 4],
#  [28, 4, 42],
#  [28, 4, 42, 15],
#  [28, 4, 42, 15, 20],
#  [28, 4, 42, 15, 20, 659],
#  [28, 4, 42, 15, 20, 659, 58],
#  [28, 4, 42, 15, 20, 659, 58, 124],
#  [28, 4, 42, 15, 20, 659, 58, 124, 407],
#  [28, 4, 42, 15, 20, 659, 58, 124, 407, 660],
#  [28, 4, 42, 15, 20, 659, 58, 124, 407, 660, 22],
#  [28, 4, 42, 15, 20, 659, 58, 124, 407, 660, 22, 1],
#  [28, 4, 42, 15, 20, 659, 58, 124, 407, 660, 22, 1, 85],
#  [28, 4, 42, 15, 20, 659, 58, 124, 407, 660, 22, 1, 85, 260],
#  [170, 188],
#  [170, 188, 189],
#  [170, 188, 189, 4],
#  [170, 188, 189, 4, 32],
#  [170, 188, 189, 4, 32, 3],
#  [170, 188, 189, 4, 32, 3, 30],
#  [170, 188, 189, 4, 32, 3, 30, 67],
#  [170, 188, 189, 4, 32, 3, 30, 67, 108],
#  [170, 188, 189, 4, 32, 3, 30, 67, 108, 408],
#  [288, 38],
#  [288, 38, 42],
#  [288, 38, 42, 29],
#  [288, 38, 42, 29, 259],
#  [288, 38, 42, 29, 259, 4],
#  [288, 38, 42, 29, 259, 4, 108],
#  [288, 38, 42, 29, 259, 4, 108, 15],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20, 222],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20, 222, 409],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20, 222, 409, 410],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20, 222, 409, 410, 411],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20, 222, 409, 410, 411, 124],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20, 222, 409, 410, 411, 124, 1],
#  [288, 38, 42, 29, 259, 4, 108, 15, 30, 20, 222, 409, 410, 411, 124, 1, 58],
#  [288, 188],
#  [288, 188, 189],
#  [288, 188, 189, 51],
#  [288, 188, 189, 51, 13],
#  [288, 188, 189, 51, 13, 85],
#  [288, 188, 189, 51, 13, 85, 294],
#  [288, 188, 189, 51, 13, 85, 294, 1],
#  [288, 188, 189, 51, 13, 85, 294, 1, 70],
#  [288, 188, 189, 51, 13, 85, 294, 1, 70, 260],
#  [5, 24],
#  [5, 24, 8],
#  [5, 24, 8, 182],
#  [5, 24, 8, 182, 1],
#  [5, 24, 8, 182, 1, 661],
#  [5, 24, 8, 182, 1, 661, 134],
#  [31, 662],
#  [31, 662, 1],
#  [31, 662, 1, 7],
#  [31, 662, 1, 7, 223],
#  [31, 662, 1, 7, 223, 133],
#  [31, 662, 1, 7, 223, 133, 31],
#  [31, 662, 1, 7, 223, 133, 31, 75],
#  [31, 662, 1, 7, 223, 133, 31, 75, 3],
#  [31, 662, 1, 7, 223, 133, 31, 75, 3, 2],
#  [31, 662, 1, 7, 223, 133, 31, 75, 3, 2, 37],
#  [2, 57],
#  [2, 57, 87],
#  [2, 57, 87, 663],
#  [2, 57, 87, 663, 17],
#  [2, 57, 87, 663, 17, 12],
#  [2, 57, 87, 663, 17, 12, 664],
#  [2, 57, 87, 663, 17, 12, 664, 3],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58, 145],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58, 145, 412],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58, 145, 412, 1],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58, 145, 412, 1, 55],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58, 145, 412, 1, 55, 295],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58, 145, 412, 1, 55, 295, 13],
#  [2, 57, 87, 663, 17, 12, 664, 3, 171, 58, 145, 412, 1, 55, 295, 13, 665],
#  [2, 413],
#  [2, 413, 3],
#  [2, 413, 3, 5],
#  [2, 413, 3, 5, 4],
#  [2, 413, 3, 5, 4, 34],
#  [2, 413, 3, 5, 4, 34, 16],
#  ...]

# %%
len_of_sequence = [len(x) for x in input_sequence]

# %%
max_len = max(len_of_sequence)
max_len
# Out:
# 27

# %%
# Padding 
padded_input_sequences = pad_sequences(input_sequence, maxlen=max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   5,   4],
#        [  0,   0,   0, ...,   5,   4,   8],
#        [  0,   0,   0, ...,   4,   8, 141],
#        ...,
#        [  0,   0,   0, ...,   2,  14, 388],
#        [  0,   0,   0, ...,  14, 388,   3],
#        [  0,   0,   0, ..., 388,   3,   5]], shape=(4524, 27), dtype=int32)

# %%
X = padded_input_sequences[:, :-1]
